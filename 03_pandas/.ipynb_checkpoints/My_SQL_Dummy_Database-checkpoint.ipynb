# %%
pip install mysql-connector-python pandas
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/16.5 MB 10.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.5 MB 12.8 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/16.5 MB 9.7 MB/s eta 0:00:02
#    --------------- ------------------------ 6.6/16.5 MB 8.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/16.5 MB 7.4 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.5 MB 6.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.5 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.5 MB 6.5 MB/s eta 0:00:01
#    --------------------------- ------------ 11.3/16.5 MB 6.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.1/16.5 MB 6.2 MB/s eta 0:00:01
# ...

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

def fetch_table(host, user, password, database, table_name):
    try:
        # Connect to MySQL
        connection = mysql.connector.connect(
            host=host,
            user=user,
            password=password,
            database=database
        )

        if connection.is_connected():
            print(f"Connected to MySQL database: {database}")

            # Use pandas to read SQL table into DataFrame
            query = f"SELECT * FROM `{table_name}`"
            df = pd.read_sql(query, connection)

            return df

    except Error as e:
        print(f"Error: {e}")
        return None

    finally:
        if 'connection' in locals() and connection.is_connected():
            connection.close()
            print("MySQL connection closed.")

# Example usage
if __name__ == "__main__":
    host = "localhost"       # MySQL server host
    user = "root"            # MySQL username
    password = "parth004"  # MySQL password
    database = "dummy"      # Database name
    table_name = "employees" # Table name

    df = fetch_table(host, user, password, database, table_name)
    if df is not None:
        print(df)
# Out:
# Connected to MySQL database: dummy
# MySQL connection closed.
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# ...

# %%
! git add .

# %%
# !git commit -m "Imported MYSQL Database into Python Using AI Assistance"
# Out:
# [main 1c2345a] Imported MYSQL Database into Python Using AI Assistance
#  4 files changed, 342 insertions(+), 20 deletions(-)
#  create mode 100644 03_pandas/.ipynb_checkpoints/My_SQL_Dummy_Database-checkpoint.ipynb
#  create mode 100644 03_pandas/My_SQL_Dummy_Database.ipynb

# %%
! git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    2c9365f..1c2345a  main -> main
