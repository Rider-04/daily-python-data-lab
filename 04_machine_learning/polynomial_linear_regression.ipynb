# %%
#polynomial linear regression

# %%
# !git add .

# %%
# !git commit -m "Polynomial Linear regression"
# Out:
# [main f1a6a70] Polynomial Linear regression
#  3 files changed, 56 insertions(+), 236 deletions(-)
#  create mode 100644 04_machine_learning/Untitled.ipynb

# %%
# !git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    ad65628..f1a6a70  main -> main
