# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
mean_absolute_error,
mean_squared_error,
root_mean_squared_error,
r2_score
)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"multiple_linear_regression_dataset.csv")

# %%
data.columns
# Out:
# Index(['age', 'experience', 'income'], dtype='object')

# %%
data.shape
# Out:
# (20, 3)

# %%
X = data.drop(columns = ["income"])

# %%
X
# Out:
#     age  experience
# 0    25           1
# 1    30           3
# 2    47           2
# 3    32           5
# 4    43          10
# 5    51           7
# 6    28           5
# 7    33           4
# 8    37           5
# 9    39           8
# 10   29           1
# 11   47           9
# 12   54           5
# 13   51           4
# 14   44          12
# 15   41           6
# 16   58          17
# 17   23           1
# 18   44           9
# 19   37          10

# %%
y = data["income"]

# %%
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
sns.pairplot(data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42,test_size = 0.2)

# %%
y_train.shape
# Out:
# (16,)

# %%
mlr = LinearRegression()

# %%
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
##Evaluation
y_pred = mlr.predict(X_test)

# %%
X_test
# Out:
#     age  experience
# 0    25           1
# 17   23           1
# 15   41           6
# 1    30           3

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 797.9113810821882

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 753796.7693734556

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 868.214702348132

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9387098237077885

# %% [markdown]
# ## SLR

# %%
X  = X.drop(columns = "age")

# %%
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
X_train_, X_test_, y_train_, y_test_ = train_test_split(X,y, random_state = 42,test_size = 0.2)

# %%
X_train_
# Out:
#     experience
# 8            5
# 5            7
# 11           9
# 3            5
# 18           9
# 16          17
# 13           4
# 2            2
# 9            8
# 19          10
# 4           10
# 12           5
# 7            4
# 10           1
# 14          12
# 6            5

# %%
slr = LinearRegression()

# %%
slr.fit(X_train_,y_train_)
# Out:
# LinearRegression()

# %%
y_predict = slr.predict(X_test_)

# %%
## evaluation

# %%
mean_absolute_error(y_test_, y_predict)
# Out:
# 1061.2724626676772

# %%
mean_squared_error(y_test_, y_predict)
# Out:
# 1313722.2998835794

# %%
root_mean_squared_error(y_test_, y_predict)
# Out:
# 1146.1772550018516

# %%
r2_score(y_test_, y_predict)
# Out:
# 0.8931830506174766

# %%
y_p = slr.predict(X)

# %%
plt.scatter(X,y)
plt.plot(X,y_p,color = "r")
plt.show()
