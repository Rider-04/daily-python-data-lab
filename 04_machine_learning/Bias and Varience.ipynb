# %%
# Gradient Descent
# there are three types of gradient descent 
# 1. Batch GD
# 2. Stochastic GD
# 3. Mini-Batch GD

# %%
# Bias = 1/Varience

# %%
# !git add .

# %%
# !git commit -m "Learned About Bias and Varience"
# Out:
# [main b5e9bd9] Learned About Bias and Varience
#  2 files changed, 14 insertions(+), 14 deletions(-)
#  rename 04_machine_learning/.ipynb_checkpoints/{gradient_descent-checkpoint.ipynb => Bias and Varience-checkpoint.ipynb} (100%)
#  rename 04_machine_learning/{gradient_descent.ipynb => Bias and Varience.ipynb} (65%)

# %%
# !git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    4405250..b5e9bd9  main -> main
