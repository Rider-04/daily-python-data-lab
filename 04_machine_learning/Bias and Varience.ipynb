# %%
# Gradient Descent
# there are three types of gradient descent 
# 1. Batch GD
# 2. Stochastic GD
# 3. Mini-Batch GD

# %%
# !git add .

# %%
# !git commit -m "Learned About types of Gradient Descent"
# Out:
# [main 4405250] Learned About types of Gradient Descent
#  1 file changed, 170 insertions(+), 350 deletions(-)

# %%
# !git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    c87a116..4405250  main -> main
