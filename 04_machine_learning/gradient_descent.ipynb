# %%
# Gradient Descent

# %%
# !git add .

# %%
# !git commit -m "Learned About Gradient Descent"
# Out:
# [main 13aa7c2] Learned About Gradient Descent
#  3 files changed, 117 insertions(+), 4 deletions(-)
#  create mode 100644 04_machine_learning/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 04_machine_learning/Untitled.ipynb

# %%
# !git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    ee51247..13aa7c2  main -> main
