# %%
# Started Leaning API (Application Programming Interface)

# %%
# !git add .

# %%
# !git commit -m "Started Leaning API (Application Programming Interface)"
# Out:
# [main ee51247] Started Leaning API (Application Programming Interface)
#  5 files changed, 131 insertions(+), 43 deletions(-)
#  create mode 100644 04_machine_learning/.ipynb_checkpoints/api-checkpoint.ipynb
#  rename 04_machine_learning/.ipynb_checkpoints/{Untitled-checkpoint.ipynb => polynomial_linear_regression-checkpoint.ipynb} (100%)
#  delete mode 100644 04_machine_learning/Untitled.ipynb
#  create mode 100644 04_machine_learning/api.ipynb
#  create mode 100644 04_machine_learning/polynomial_linear_regression.ipynb

# %%
# !git push
# Out:
# To https://github.com/Rider-04/daily-python-data-lab.git
#    f1a6a70..ee51247  main -> main
