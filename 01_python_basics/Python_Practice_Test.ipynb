# %%
from functools import reduce
l=[1,4,-2,5,8,3]
print(reduce(lambda x,y:x+y,list(map(lambda x:x*3,list(filter(lambda i:i%4!=0 and i>0,l))))))
# Out:
# 27

# %%
def addition(n):
    if n==0:
        return 0
    else:
        return addition(n//10)+n%10
addition(1234)
# Out:
# 10

# %%
n=int(input("Enter the height :-"))
for i in range(n):
    for j in range(i):
        print(' ',end=' ')
    for k in range(i,2*n-i-1):
        if i==0 or k==i or k==2*n-i-2:
            print('*',end=" ")
        else:
            print(' ',end=' ')
    print()
# Out:
# Enter the height :- 5
# * * * * * * * * *
#   *           *
#     *       *
#       *   *
#         *

# %%
# Computing whether a number is an Armstrong number using
# recursion involves a recursive function that can calculate the sum of
# the digits of the number raised to the power of the number of digits.
m=int(input("Enter any number:-"))
a=len(str(m))
old=n
sm=0
while m!=0:
    last_dig=n%10
    sm=sm+(last_dig**a)
    m=m//10
if old==sm:
    print("Armstrong")

def arm(n):
    if n==0:
        return 0
    else:
        return arm(n//2)+(n%10)**len(str(n))
for i in range()
# Out:
# Enter any number:- 10
# Armstrong

# %%
def arm(n,a):
    if n==0:
        return 0
    return ((n%10)**a)+arm(n//10,a)
n=int(input("Enter any number:-"))
a=len(str(n))
if arm(n,a)==n:
    print(n,"armstrong")
else:
    print(n,"not armstrong")
# Out:
# Enter any number:- 153
# 153 armstrong

# %%
# Computing whether a number is an Armstrong number using
# recursion involves a recursive function that can
# calculate the sum of
# the digits of the number raised to the power of the number of digits.
def fib(n):
    if n==1:
        return (0,end=' ')
    elif n==2:
        return (0,1,end=' ')
# Out:
#   Cell In[6], line 3
#     calculate the sum of
#               ^
# SyntaxError: invalid syntax

# %%
def append_to_sequence(seq=[]):
    seq.append(len(seq) + 1)
    return seq
print(append_to_sequence())
# print(append_to_sequence([1, 2, 3]))
print(append_to_sequence())
# Out:
# [1]
# [1, 2]
